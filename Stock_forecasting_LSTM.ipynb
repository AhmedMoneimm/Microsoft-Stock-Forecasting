# %% [markdown]
# # **Dataset**
#
# >  Get dataset from https://finance.yahoo.com/quote/MSFT/history/
#
# choose max in time period, then download

# %%
import pandas as pd
df=pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060524
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062686
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063767
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062145
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061065
# ...          ...         ...         ...         ...         ...         ...
# 9285  2023-01-13  237.000000  239.369995  234.919998  239.229996  238.111755
# 9286  2023-01-17  237.970001  240.910004  237.089996  240.350006  239.226532
# 9287  2023-01-18  241.570007  242.380005  235.520004  235.809998  234.707748
# 9288  2023-01-19  233.779999  235.520004  230.679993  231.929993  230.845886
# 9289  2023-01-20  234.860001  240.740005  234.509995  240.220001  239.097153
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9285    21333300
# 9286    29831300
# 9287    30028700
# 9288    28623000
# 9289    35389800
#
# [9290 rows x 7 columns]

# %%
df = df[['Date','Close']]

df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9285  2023-01-13  239.229996
# 9286  2023-01-17  240.350006
# 9287  2023-01-18  235.809998
# 9288  2023-01-19  231.929993
# 9289  2023-01-20  240.220001
#
# [9290 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1986-03-13
# 1       1986-03-14
# 2       1986-03-17
# 3       1986-03-18
# 4       1986-03-19
#            ...
# 9285    2023-01-13
# 9286    2023-01-17
# 9287    2023-01-18
# 9288    2023-01-19
# 9289    2023-01-20
# Name: Date, Length: 9290, dtype: object

# %% [markdown]
# ## change the type from string to datetime

# %%
import datetime

def str_to_datetime(str):
  split = str.split('-')
  y, m, d = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=y, month=m, day=d)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)

df['Date']
# Out:
# <ipython-input-5-a035e129bcba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9285   2023-01-13
# 9286   2023-01-17
# 9287   2023-01-18
# 9288   2023-01-19
# 9289   2023-01-20
# Name: Date, Length: 9290, dtype: datetime64[ns]

# %% [markdown]
# # we want the 'Date' to be the index

# %%
df.index = df.pop('Date')

df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-01-13  239.229996
# 2023-01-17  240.350006
# 2023-01-18  235.809998
# 2023-01-19  231.929993
# 2023-01-20  240.220001
#
# [9290 rows x 1 columns]

# %% [markdown]
# # Plot the data

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2018-03-25', # start
                                '2023-01-20', # end(today)
                                n=3) 
# time was taken from 2018 till today and before 2018 was ignored, as the graph above shows the huge difference in gradient between before and after 2018
# as the data before 2018 would damage the results

windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     2018-03-25   93.129997   92.480003   89.790001   87.180000
# 1     2018-03-27   89.790001   87.180000   93.779999   89.470001
# 2     2018-03-28   87.180000   93.779999   89.470001   89.389999
# 3     2018-03-29   93.779999   89.470001   89.389999   91.269997
# 4     2018-04-02   89.470001   89.389999   91.269997   88.519997
# ...          ...         ...         ...         ...         ...
# 1210  2023-01-13  228.850006  235.770004  238.509995  239.229996
# 1211  2023-01-17  235.770004  238.509995  239.229996  240.350006
# 1212  2023-01-18  238.509995  239.229996  240.350006  235.809998
# 1213  2023-01-19  239.229996  240.350006  235.809998  231.929993
# 1214  2023-01-20  240.350006  235.809998  231.929993  240.220001
#
# [1215 rows x 5 columns]

# %% [markdown]
# target-3....target-1 are inputs, target is the output
#
# note -3 means the value 3 days before the date

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((1215,), (1215, 3, 1), (1215,))

# %% [markdown]
# date: coloumn
# X: 3d matrix
# y: output

# %% [markdown]
# # **Split the data into train, test and validation**
#
# > train = 0.8
#
# > validation = 0.1
#
# > test = 0.1

# %%
q_80 = int(len(dates)*0.8)
q_90 = int(len(dates)*0.9)

dates_train, X_train, y_train = dates[ :q_80], X[ :q_80], y[ :q_80] # first 80%
dates_val, X_val, y_val = dates[q_80 : q_90], X[q_80 : q_90], y[q_80 : q_90] # 10% - 80% to 90%
dates_test, X_test, y_test = dates[q_90: ], X[q_90: ], y[q_90: ] # 10% - 90% to 10%

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %% [markdown]
# # **Make Model and tarin it**

# %%
from tensorflow.keras.models import Sequential # Sequential model
from tensorflow.keras.optimizers import Adam # optimizer type
from tensorflow.keras import layers

model = Sequential([
    layers.Input((3, 1)), # 3 inputs, one output
    layers.LSTM(64), # big but not really big num of neurons, the bigger the num the more complicated the model is and more prone to overfit, the more heavy duty
    layers.Dense(32, activation='relu'), # put activiation for the dense, not the LSTM
    layers.Dense(32, activation='relu'),
    layers.Dense(1) # linear
])

model.compile(loss = 'mse', 
              optimizer = Adam(learning_rate=0.001), # mean sqr error
              metrics = ['mean_absolute_error']
              )

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150)
# Out:
# Epoch 1/150
# 31/31 [==============================] - 9s 83ms/step - loss: 38327.9883 - mean_absolute_error: 182.2007 - val_loss: 76738.2812 - val_mean_absolute_error: 276.3555
# Epoch 2/150
# 31/31 [==============================] - 0s 13ms/step - loss: 37001.8516 - mean_absolute_error: 178.4678 - val_loss: 73177.6328 - val_mean_absolute_error: 269.8329
# Epoch 3/150
# 31/31 [==============================] - 0s 13ms/step - loss: 32117.9863 - mean_absolute_error: 164.0346 - val_loss: 60495.8086 - val_mean_absolute_error: 245.2137
# Epoch 4/150
# 31/31 [==============================] - 0s 16ms/step - loss: 21457.4609 - mean_absolute_error: 125.8117 - val_loss: 36195.1680 - val_mean_absolute_error: 189.2790
# Epoch 5/150
# 31/31 [==============================] - 0s 14ms/step - loss: 8827.2656 - mean_absolute_error: 70.8648 - val_loss: 13300.2773 - val_mean_absolute_error: 113.7301
# Epoch 6/150
# 31/31 [==============================] - 1s 18ms/step - loss: 4915.8232 - mean_absolute_error: 60.0377 - val_loss: 8145.9248 - val_mean_absolute_error: 88.3870
# Epoch 7/150
# 31/31 [==============================] - 1s 17ms/step - loss: 3261.3945 - mean_absolute_error: 46.7343 - val_loss: 5035.0010 - val_mean_absolute_error: 68.6237
# Epoch 8/150
# 31/31 [==============================] - 0s 14ms/step - loss: 1098.6027 - mean_absolute_error: 18.6974 - val_loss: 939.6061 - val_mean_absolute_error: 25.8887
# Epoch 9/150
# 31/31 [==============================] - 1s 17ms/step - loss: 273.0296 - mean_absolute_error: 7.7650 - val_loss: 111.2262 - val_mean_absolute_error: 8.1199
# Epoch 10/150
# 31/31 [==============================] - 0s 14ms/step - loss: 86.7111 - mean_absolute_error: 4.6245 - val_loss: 73.9780 - val_mean_absolute_error: 6.8972
# Epoch 11/150
# 31/31 [==============================] - 0s 11ms/step - loss: 46.0073 - mean_absolute_error: 3.7996 - val_loss: 45.8290 - val_mean_absolute_error: 5.5301
# Epoch 12/150
# 31/31 [==============================] - 0s 16ms/step - loss: 31.2996 - mean_absolute_error: 3.4093 - val_loss: 46.6823 - val_mean_absolute_error: 5.6210
# Epoch 13/150
# 31/31 [==============================] - 0s 15ms/step - loss: 25.7240 - mean_absolute_error: 3.3503 - val_loss: 45.0280 - val_mean_absolute_error: 5.4963
# Epoch 14/150
# 31/31 [==============================] - 0s 14ms/step - loss: 20.7420 - mean_absolute_error: 3.0651 - val_loss: 50.3405 - val_mean_absolute_error: 5.9345
# Epoch 15/150
# 31/31 [==============================] - 0s 11ms/step - loss: 19.4138 - mean_absolute_error: 3.0948 - val_loss: 59.7363 - val_mean_absolute_error: 6.2003
# Epoch 16/150
# 31/31 [==============================] - 0s 13ms/step - loss: 17.0429 - mean_absolute_error: 2.8035 - val_loss: 51.1113 - val_mean_absolute_error: 5.9491
# Epoch 17/150
# 31/31 [==============================] - 1s 18ms/step - loss: 20.0325 - mean_absolute_error: 3.3082 - val_loss: 48.2115 - val_mean_absolute_error: 5.7399
# Epoch 18/150
# 31/31 [==============================] - 0s 16ms/step - loss: 20.7414 - mean_absolute_error: 3.3144 - val_loss: 68.7629 - val_mean_absolute_error: 6.5317
# Epoch 19/150
# 31/31 [==============================] - 0s 14ms/step - loss: 19.0078 - mean_absolute_error: 3.1463 - val_loss: 42.5730 - val_mean_absolute_error: 5.4180
# Epoch 20/150
# 31/31 [==============================] - 0s 8ms/step - loss: 14.1635 - mean_absolute_error: 2.6450 - val_loss: 46.5846 - val_mean_absolute_error: 5.6817
# Epoch 21/150
# 31/31 [==============================] - 0s 7ms/step - loss: 17.3170 - mean_absolute_error: 2.9470 - val_loss: 46.1364 - val_mean_absolute_error: 5.6256
# Epoch 22/150
# 31/31 [==============================] - 0s 7ms/step - loss: 18.4450 - mean_absolute_error: 3.1627 - val_loss: 56.0982 - val_mean_absolute_error: 5.9175
# Epoch 23/150
# 31/31 [==============================] - 0s 9ms/step - loss: 14.3969 - mean_absolute_error: 2.6789 - val_loss: 81.8533 - val_mean_absolute_error: 7.2359
# Epoch 24/150
# 31/31 [==============================] - 0s 10ms/step - loss: 18.0690 - mean_absolute_error: 3.0814 - val_loss: 56.9249 - val_mean_absolute_error: 6.2515
# Epoch 25/150
# 31/31 [==============================] - 0s 11ms/step - loss: 17.0326 - mean_absolute_error: 3.0455 - val_loss: 40.2761 - val_mean_absolute_error: 5.2077
# Epoch 26/150
# 31/31 [==============================] - 0s 10ms/step - loss: 15.3660 - mean_absolute_error: 2.8015 - val_loss: 44.1207 - val_mean_absolute_error: 5.4341
# Epoch 27/150
# 31/31 [==============================] - 0s 10ms/step - loss: 14.4627 - mean_absolute_error: 2.6896 - val_loss: 42.4448 - val_mean_absolute_error: 5.3593
# Epoch 28/150
# 31/31 [==============================] - 0s 10ms/step - loss: 14.9900 - mean_absolute_error: 2.8177 - val_loss: 68.8269 - val_mean_absolute_error: 6.5710
# Epoch 29/150
# 31/31 [==============================] - 0s 10ms/step - loss: 16.2204 - mean_absolute_error: 2.8841 - val_loss: 48.8236 - val_mean_absolute_error: 5.5480
# Epoch 30/150
# 31/31 [==============================] - 0s 11ms/step - loss: 15.5341 - mean_absolute_error: 2.8351 - val_loss: 83.3572 - val_mean_absolute_error: 7.3883
# Epoch 31/150
# 31/31 [==============================] - 0s 12ms/step - loss: 15.0124 - mean_absolute_error: 2.8431 - val_loss: 38.5165 - val_mean_absolute_error: 5.0668
# Epoch 32/150
# 31/31 [==============================] - 0s 9ms/step - loss: 15.4725 - mean_absolute_error: 2.9245 - val_loss: 54.9543 - val_mean_absolute_error: 5.9538
# Epoch 33/150
# 31/31 [==============================] - 0s 7ms/step - loss: 14.6146 - mean_absolute_error: 2.7428 - val_loss: 41.4724 - val_mean_absolute_error: 5.2146
# Epoch 34/150
# 31/31 [==============================] - 0s 8ms/step - loss: 13.0190 - mean_absolute_error: 2.5620 - val_loss: 55.3751 - val_mean_absolute_error: 5.8737
# Epoch 35/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.1182 - mean_absolute_error: 2.6220 - val_loss: 127.6842 - val_mean_absolute_error: 9.5500
# Epoch 36/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.1616 - mean_absolute_error: 2.7210 - val_loss: 44.1195 - val_mean_absolute_error: 5.4397
# Epoch 37/150
# 31/31 [==============================] - 0s 6ms/step - loss: 13.7189 - mean_absolute_error: 2.6376 - val_loss: 56.3859 - val_mean_absolute_error: 5.9277
# Epoch 38/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.9128 - mean_absolute_error: 2.6258 - val_loss: 52.7147 - val_mean_absolute_error: 5.7444
# Epoch 39/150
# 31/31 [==============================] - 0s 7ms/step - loss: 14.1403 - mean_absolute_error: 2.6835 - val_loss: 52.2886 - val_mean_absolute_error: 5.8423
# Epoch 40/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.2749 - mean_absolute_error: 2.8828 - val_loss: 56.1630 - val_mean_absolute_error: 5.9260
# Epoch 41/150
# 31/31 [==============================] - 0s 6ms/step - loss: 13.8056 - mean_absolute_error: 2.5522 - val_loss: 58.9206 - val_mean_absolute_error: 6.3574
# Epoch 42/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.7442 - mean_absolute_error: 2.9232 - val_loss: 44.0891 - val_mean_absolute_error: 5.4344
# Epoch 43/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.8667 - mean_absolute_error: 2.6499 - val_loss: 57.3045 - val_mean_absolute_error: 5.9586
# Epoch 44/150
# 31/31 [==============================] - 0s 8ms/step - loss: 12.9119 - mean_absolute_error: 2.4963 - val_loss: 38.8006 - val_mean_absolute_error: 5.0674
# Epoch 45/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.8961 - mean_absolute_error: 2.6399 - val_loss: 41.2882 - val_mean_absolute_error: 5.2671
# Epoch 46/150
# 31/31 [==============================] - 0s 7ms/step - loss: 16.1136 - mean_absolute_error: 2.9498 - val_loss: 93.3246 - val_mean_absolute_error: 7.7934
# Epoch 47/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.1626 - mean_absolute_error: 2.7680 - val_loss: 50.9134 - val_mean_absolute_error: 5.6431
# Epoch 48/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.4478 - mean_absolute_error: 2.8599 - val_loss: 46.7420 - val_mean_absolute_error: 5.4764
# Epoch 49/150
# 31/31 [==============================] - 0s 8ms/step - loss: 12.4453 - mean_absolute_error: 2.4613 - val_loss: 43.5055 - val_mean_absolute_error: 5.3071
# Epoch 50/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.5929 - mean_absolute_error: 2.5105 - val_loss: 46.9735 - val_mean_absolute_error: 5.6070
# Epoch 51/150
# 31/31 [==============================] - 0s 8ms/step - loss: 13.9364 - mean_absolute_error: 2.6358 - val_loss: 38.2941 - val_mean_absolute_error: 5.0471
# Epoch 52/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.2321 - mean_absolute_error: 2.8781 - val_loss: 46.1017 - val_mean_absolute_error: 5.4639
# Epoch 53/150
# 31/31 [==============================] - 0s 8ms/step - loss: 12.8909 - mean_absolute_error: 2.5106 - val_loss: 56.7544 - val_mean_absolute_error: 5.9295
# Epoch 54/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.0635 - mean_absolute_error: 2.5091 - val_loss: 41.8448 - val_mean_absolute_error: 5.2748
# Epoch 55/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.7276 - mean_absolute_error: 2.5068 - val_loss: 39.6649 - val_mean_absolute_error: 5.1040
# Epoch 56/150
# 31/31 [==============================] - 0s 7ms/step - loss: 14.7137 - mean_absolute_error: 2.7612 - val_loss: 73.9011 - val_mean_absolute_error: 6.8230
# Epoch 57/150
# 31/31 [==============================] - 0s 8ms/step - loss: 13.1333 - mean_absolute_error: 2.5354 - val_loss: 46.9138 - val_mean_absolute_error: 5.5056
# Epoch 58/150
# 31/31 [==============================] - 0s 8ms/step - loss: 16.7593 - mean_absolute_error: 2.9459 - val_loss: 42.5957 - val_mean_absolute_error: 5.3474
# Epoch 59/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.2935 - mean_absolute_error: 2.4667 - val_loss: 51.8760 - val_mean_absolute_error: 5.6904
# Epoch 60/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.2296 - mean_absolute_error: 2.5550 - val_loss: 47.5337 - val_mean_absolute_error: 5.5499
# Epoch 61/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.0880 - mean_absolute_error: 2.5177 - val_loss: 62.8422 - val_mean_absolute_error: 6.2958
# Epoch 62/150
# 31/31 [==============================] - 0s 8ms/step - loss: 14.0223 - mean_absolute_error: 2.6370 - val_loss: 45.1624 - val_mean_absolute_error: 5.3718
# Epoch 63/150
# 31/31 [==============================] - 0s 6ms/step - loss: 12.8897 - mean_absolute_error: 2.4702 - val_loss: 48.0537 - val_mean_absolute_error: 5.5438
# Epoch 64/150
# 31/31 [==============================] - 0s 7ms/step - loss: 14.0908 - mean_absolute_error: 2.6584 - val_loss: 39.7539 - val_mean_absolute_error: 5.1624
# Epoch 65/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.4667 - mean_absolute_error: 2.5896 - val_loss: 54.6077 - val_mean_absolute_error: 5.8838
# Epoch 66/150
# 31/31 [==============================] - 0s 7ms/step - loss: 14.4017 - mean_absolute_error: 2.7355 - val_loss: 58.2058 - val_mean_absolute_error: 6.0258
# Epoch 67/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.8917 - mean_absolute_error: 2.6114 - val_loss: 48.1356 - val_mean_absolute_error: 5.7091
# Epoch 68/150
# 31/31 [==============================] - 0s 6ms/step - loss: 15.2262 - mean_absolute_error: 2.8308 - val_loss: 39.6327 - val_mean_absolute_error: 5.1475
# Epoch 69/150
# 31/31 [==============================] - 0s 7ms/step - loss: 11.9948 - mean_absolute_error: 2.4014 - val_loss: 40.0169 - val_mean_absolute_error: 5.1589
# Epoch 70/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.7339 - mean_absolute_error: 2.5603 - val_loss: 49.5796 - val_mean_absolute_error: 5.7756
# Epoch 71/150
# 31/31 [==============================] - 0s 7ms/step - loss: 14.6074 - mean_absolute_error: 2.6963 - val_loss: 43.7391 - val_mean_absolute_error: 5.3628
# Epoch 72/150
# 31/31 [==============================] - 0s 8ms/step - loss: 15.4911 - mean_absolute_error: 2.7909 - val_loss: 40.4794 - val_mean_absolute_error: 5.2270
# Epoch 73/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.0827 - mean_absolute_error: 2.7848 - val_loss: 60.2084 - val_mean_absolute_error: 6.1202
# Epoch 74/150
# 31/31 [==============================] - 0s 8ms/step - loss: 13.7850 - mean_absolute_error: 2.5983 - val_loss: 89.1099 - val_mean_absolute_error: 7.6090
# Epoch 75/150
# 31/31 [==============================] - 0s 9ms/step - loss: 15.7102 - mean_absolute_error: 2.8178 - val_loss: 96.7421 - val_mean_absolute_error: 8.1218
# Epoch 76/150
# 31/31 [==============================] - 0s 11ms/step - loss: 13.3081 - mean_absolute_error: 2.5576 - val_loss: 41.5407 - val_mean_absolute_error: 5.2304
# Epoch 77/150
# 31/31 [==============================] - 0s 10ms/step - loss: 15.3813 - mean_absolute_error: 2.7693 - val_loss: 40.1237 - val_mean_absolute_error: 5.1563
# Epoch 78/150
# 31/31 [==============================] - 0s 10ms/step - loss: 12.6569 - mean_absolute_error: 2.5154 - val_loss: 52.3345 - val_mean_absolute_error: 5.9589
# Epoch 79/150
# 31/31 [==============================] - 0s 10ms/step - loss: 17.2372 - mean_absolute_error: 3.0188 - val_loss: 43.0065 - val_mean_absolute_error: 5.4138
# Epoch 80/150
# 31/31 [==============================] - 0s 11ms/step - loss: 13.7731 - mean_absolute_error: 2.6023 - val_loss: 42.0879 - val_mean_absolute_error: 5.3651
# Epoch 81/150
# 31/31 [==============================] - 0s 11ms/step - loss: 12.6824 - mean_absolute_error: 2.4788 - val_loss: 40.6300 - val_mean_absolute_error: 5.2243
# Epoch 82/150
# 31/31 [==============================] - 0s 11ms/step - loss: 13.1130 - mean_absolute_error: 2.5312 - val_loss: 39.7780 - val_mean_absolute_error: 5.1765
# Epoch 83/150
# 31/31 [==============================] - 0s 11ms/step - loss: 11.7037 - mean_absolute_error: 2.3995 - val_loss: 39.7899 - val_mean_absolute_error: 5.1760
# Epoch 84/150
# 31/31 [==============================] - 0s 10ms/step - loss: 13.2544 - mean_absolute_error: 2.6379 - val_loss: 40.5258 - val_mean_absolute_error: 5.1939
# Epoch 85/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.1708 - mean_absolute_error: 2.6337 - val_loss: 41.8945 - val_mean_absolute_error: 5.3130
# Epoch 86/150
# 31/31 [==============================] - 0s 7ms/step - loss: 14.0049 - mean_absolute_error: 2.6331 - val_loss: 39.4932 - val_mean_absolute_error: 5.1201
# Epoch 87/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.3875 - mean_absolute_error: 2.4584 - val_loss: 40.5170 - val_mean_absolute_error: 5.2000
# Epoch 88/150
# 31/31 [==============================] - 0s 6ms/step - loss: 14.7640 - mean_absolute_error: 2.6960 - val_loss: 56.9132 - val_mean_absolute_error: 6.2070
# Epoch 89/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.7807 - mean_absolute_error: 2.9118 - val_loss: 39.3931 - val_mean_absolute_error: 5.1497
# Epoch 90/150
# 31/31 [==============================] - 0s 6ms/step - loss: 12.3168 - mean_absolute_error: 2.4829 - val_loss: 41.1901 - val_mean_absolute_error: 5.2372
# Epoch 91/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.1295 - mean_absolute_error: 2.6099 - val_loss: 47.2589 - val_mean_absolute_error: 5.4886
# Epoch 92/150
# 31/31 [==============================] - 0s 7ms/step - loss: 17.5566 - mean_absolute_error: 3.0566 - val_loss: 46.3951 - val_mean_absolute_error: 5.4639
# Epoch 93/150
# 31/31 [==============================] - 0s 6ms/step - loss: 12.2218 - mean_absolute_error: 2.4644 - val_loss: 39.2035 - val_mean_absolute_error: 5.1107
# Epoch 94/150
# 31/31 [==============================] - 0s 8ms/step - loss: 13.2255 - mean_absolute_error: 2.5412 - val_loss: 77.2802 - val_mean_absolute_error: 7.0044
# Epoch 95/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.4140 - mean_absolute_error: 2.5960 - val_loss: 60.9443 - val_mean_absolute_error: 6.1460
# Epoch 96/150
# 31/31 [==============================] - 0s 8ms/step - loss: 18.8482 - mean_absolute_error: 3.1561 - val_loss: 156.3568 - val_mean_absolute_error: 10.9658
# Epoch 97/150
# 31/31 [==============================] - 0s 7ms/step - loss: 22.7043 - mean_absolute_error: 3.5248 - val_loss: 43.6698 - val_mean_absolute_error: 5.3056
# Epoch 98/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.4765 - mean_absolute_error: 2.6656 - val_loss: 39.4895 - val_mean_absolute_error: 5.1264
# Epoch 99/150
# 31/31 [==============================] - 0s 8ms/step - loss: 12.6834 - mean_absolute_error: 2.4916 - val_loss: 70.0542 - val_mean_absolute_error: 6.7057
# Epoch 100/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.5185 - mean_absolute_error: 2.8498 - val_loss: 92.7609 - val_mean_absolute_error: 7.7718
# Epoch 101/150
# 31/31 [==============================] - 0s 8ms/step - loss: 15.3948 - mean_absolute_error: 2.8170 - val_loss: 48.0948 - val_mean_absolute_error: 5.5587
# Epoch 102/150
# 31/31 [==============================] - 0s 7ms/step - loss: 11.9028 - mean_absolute_error: 2.3842 - val_loss: 75.2176 - val_mean_absolute_error: 6.9132
# Epoch 103/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.6283 - mean_absolute_error: 2.6184 - val_loss: 40.8723 - val_mean_absolute_error: 5.2221
# Epoch 104/150
# 31/31 [==============================] - 0s 7ms/step - loss: 11.9463 - mean_absolute_error: 2.4349 - val_loss: 42.7228 - val_mean_absolute_error: 5.3732
# Epoch 105/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.2902 - mean_absolute_error: 2.5051 - val_loss: 41.3570 - val_mean_absolute_error: 5.2598
# Epoch 106/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.7691 - mean_absolute_error: 2.6171 - val_loss: 40.5974 - val_mean_absolute_error: 5.2083
# Epoch 107/150
# 31/31 [==============================] - 0s 8ms/step - loss: 17.1668 - mean_absolute_error: 3.0425 - val_loss: 38.8976 - val_mean_absolute_error: 5.0802
# Epoch 108/150
# 31/31 [==============================] - 0s 6ms/step - loss: 20.2994 - mean_absolute_error: 3.2543 - val_loss: 44.1958 - val_mean_absolute_error: 5.3680
# Epoch 109/150
# 31/31 [==============================] - 0s 7ms/step - loss: 16.5097 - mean_absolute_error: 3.0043 - val_loss: 46.2417 - val_mean_absolute_error: 5.4319
# Epoch 110/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.0690 - mean_absolute_error: 2.3896 - val_loss: 42.6381 - val_mean_absolute_error: 5.2927
# Epoch 111/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.1940 - mean_absolute_error: 2.5336 - val_loss: 43.7860 - val_mean_absolute_error: 5.3435
# Epoch 112/150
# 31/31 [==============================] - 0s 8ms/step - loss: 12.9903 - mean_absolute_error: 2.5303 - val_loss: 50.2873 - val_mean_absolute_error: 5.8095
# Epoch 113/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.9058 - mean_absolute_error: 2.6816 - val_loss: 49.2324 - val_mean_absolute_error: 5.7666
# Epoch 114/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.9936 - mean_absolute_error: 2.7044 - val_loss: 43.0408 - val_mean_absolute_error: 5.3101
# Epoch 115/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.4445 - mean_absolute_error: 2.4928 - val_loss: 39.7055 - val_mean_absolute_error: 5.1364
# Epoch 116/150
# 31/31 [==============================] - 0s 8ms/step - loss: 12.0793 - mean_absolute_error: 2.4445 - val_loss: 40.3907 - val_mean_absolute_error: 5.2424
# Epoch 117/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.8545 - mean_absolute_error: 2.6530 - val_loss: 40.5097 - val_mean_absolute_error: 5.2389
# Epoch 118/150
# 31/31 [==============================] - 0s 8ms/step - loss: 11.7935 - mean_absolute_error: 2.5001 - val_loss: 53.3094 - val_mean_absolute_error: 5.7712
# Epoch 119/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.8283 - mean_absolute_error: 2.4780 - val_loss: 42.0845 - val_mean_absolute_error: 5.3216
# Epoch 120/150
# 31/31 [==============================] - 0s 8ms/step - loss: 11.8244 - mean_absolute_error: 2.4247 - val_loss: 52.8488 - val_mean_absolute_error: 5.7412
# Epoch 121/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.0258 - mean_absolute_error: 2.5270 - val_loss: 39.1757 - val_mean_absolute_error: 5.1498
# Epoch 122/150
# 31/31 [==============================] - 0s 8ms/step - loss: 13.5678 - mean_absolute_error: 2.5950 - val_loss: 42.2833 - val_mean_absolute_error: 5.2172
# Epoch 123/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.3898 - mean_absolute_error: 2.5815 - val_loss: 46.2917 - val_mean_absolute_error: 5.4767
# Epoch 124/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.6465 - mean_absolute_error: 2.5144 - val_loss: 64.2604 - val_mean_absolute_error: 6.3276
# Epoch 125/150
# 31/31 [==============================] - 0s 7ms/step - loss: 14.7949 - mean_absolute_error: 2.7970 - val_loss: 39.7649 - val_mean_absolute_error: 5.1579
# Epoch 126/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.0942 - mean_absolute_error: 2.4295 - val_loss: 45.2075 - val_mean_absolute_error: 5.3496
# Epoch 127/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.8809 - mean_absolute_error: 2.6560 - val_loss: 64.9671 - val_mean_absolute_error: 6.5217
# Epoch 128/150
# 31/31 [==============================] - 0s 11ms/step - loss: 20.5484 - mean_absolute_error: 3.2927 - val_loss: 67.6024 - val_mean_absolute_error: 6.4399
# Epoch 129/150
# 31/31 [==============================] - 0s 10ms/step - loss: 17.9310 - mean_absolute_error: 3.1026 - val_loss: 49.2749 - val_mean_absolute_error: 5.8104
# Epoch 130/150
# 31/31 [==============================] - 0s 10ms/step - loss: 15.5391 - mean_absolute_error: 2.9527 - val_loss: 48.0633 - val_mean_absolute_error: 5.5313
# Epoch 131/150
# 31/31 [==============================] - 0s 10ms/step - loss: 12.4677 - mean_absolute_error: 2.4639 - val_loss: 41.0397 - val_mean_absolute_error: 5.2580
# Epoch 132/150
# 31/31 [==============================] - 0s 10ms/step - loss: 12.7253 - mean_absolute_error: 2.5769 - val_loss: 40.1223 - val_mean_absolute_error: 5.1801
# Epoch 133/150
# 31/31 [==============================] - 0s 9ms/step - loss: 11.9076 - mean_absolute_error: 2.4273 - val_loss: 63.7240 - val_mean_absolute_error: 6.3670
# Epoch 134/150
# 31/31 [==============================] - 0s 10ms/step - loss: 15.1015 - mean_absolute_error: 2.8042 - val_loss: 58.7371 - val_mean_absolute_error: 6.0122
# Epoch 135/150
# 31/31 [==============================] - 0s 11ms/step - loss: 12.5115 - mean_absolute_error: 2.6046 - val_loss: 47.5860 - val_mean_absolute_error: 5.6554
# Epoch 136/150
# 31/31 [==============================] - 0s 10ms/step - loss: 12.7099 - mean_absolute_error: 2.6170 - val_loss: 39.3878 - val_mean_absolute_error: 5.1647
# Epoch 137/150
# 31/31 [==============================] - 0s 9ms/step - loss: 14.1547 - mean_absolute_error: 2.7441 - val_loss: 41.3314 - val_mean_absolute_error: 5.2568
# Epoch 138/150
# 31/31 [==============================] - 0s 8ms/step - loss: 15.1871 - mean_absolute_error: 2.8218 - val_loss: 54.5300 - val_mean_absolute_error: 5.8108
# Epoch 139/150
# 31/31 [==============================] - 0s 7ms/step - loss: 15.4476 - mean_absolute_error: 2.9281 - val_loss: 40.1784 - val_mean_absolute_error: 5.1871
# Epoch 140/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.8750 - mean_absolute_error: 2.6924 - val_loss: 40.6836 - val_mean_absolute_error: 5.2384
# Epoch 141/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.8979 - mean_absolute_error: 2.5391 - val_loss: 54.1028 - val_mean_absolute_error: 5.8119
# Epoch 142/150
# 31/31 [==============================] - 0s 8ms/step - loss: 12.5409 - mean_absolute_error: 2.5515 - val_loss: 43.2030 - val_mean_absolute_error: 5.3010
# Epoch 143/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.0044 - mean_absolute_error: 2.4980 - val_loss: 42.6876 - val_mean_absolute_error: 5.3229
# Epoch 144/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.2752 - mean_absolute_error: 2.5822 - val_loss: 46.2392 - val_mean_absolute_error: 5.4829
# Epoch 145/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.2586 - mean_absolute_error: 2.4780 - val_loss: 42.0929 - val_mean_absolute_error: 5.2702
# Epoch 146/150
# 31/31 [==============================] - 0s 8ms/step - loss: 12.3452 - mean_absolute_error: 2.5713 - val_loss: 49.6746 - val_mean_absolute_error: 5.6259
# Epoch 147/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.9377 - mean_absolute_error: 2.5789 - val_loss: 40.4054 - val_mean_absolute_error: 5.2011
# Epoch 148/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.2687 - mean_absolute_error: 2.6558 - val_loss: 43.2785 - val_mean_absolute_error: 5.3754
# Epoch 149/150
# 31/31 [==============================] - 0s 7ms/step - loss: 12.8880 - mean_absolute_error: 2.5855 - val_loss: 44.0756 - val_mean_absolute_error: 5.4647
# Epoch 150/150
# 31/31 [==============================] - 0s 7ms/step - loss: 13.4047 - mean_absolute_error: 2.6458 - val_loss: 43.1040 - val_mean_absolute_error: 5.4225

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 31/31 [==============================] - 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend([
    'Training Predictions', 
    'Training Observations',
    'Validation Predictions', 
    'Validation Observations',
    'Testing Predictions', 
    'Testing Observations'
    ])

# %% [markdown]
# # **Make Long-term prediction**

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions) # added
plt.legend([
    'Training Predictions', 
    'Training Observations',
    'Validation Predictions', 
    'Validation Observations',
    'Testing Predictions', 
    'Testing Observations',
    'Recursive Predictions' # added
    ])

# %% [markdown]
# ## this graph shows that the model has no idea on how to predict values in the long term
